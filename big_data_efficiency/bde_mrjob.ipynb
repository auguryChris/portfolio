# %%
 # !pip install syllables #comment or uncomment based on if installed in environment
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Requirement already satisfied: syllables in /opt/conda/lib/python3.7/site-packages (0.1.0)

# %% [markdown]
# Note the use of the magic command ```%%file```.  You can use this to write the contents of a cell out to a file, which is what we need to do to use mrjob:

# %%
# %%file word_count.py
from mrjob.job import MRJob
import re

class MRWordFrequencyCount(MRJob):

  ### input: self, in_key, in_value
  def mapper(self, _, line):
    yield "chars", len(line)
    yield "words", len(line.split())
    yield "lines", 1

  ### input: self, in_key from mapper, in_value from mapper
  def reducer(self, key, values):
    yield key, sum(values)
if __name__ == "__main__":
    MRWordFrequencyCount.run()
# Out:
# Overwriting word_count.py

# %% [markdown]
# Then we use the bang (!) command to run the python file on a text file.

# %%
# !python word_count.py data/gutenberg/short.t1.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/word_count.jovyan.20210503.231749.743881
# Running step 1 of 1...
# job output is in /tmp/word_count.jovyan.20210503.231749.743881/output
# Streaming final output from /tmp/word_count.jovyan.20210503.231749.743881/output...
# "chars"	10653
# "words"	1822
# "lines"	200
# Removing temp directory /tmp/word_count.jovyan.20210503.231749.743881...

# %%
### Now let's look at a slightly more complicated example:

# %%
# %%file most_used_word.py
from mrjob.job import MRJob
from mrjob.step import MRStep
import re

WORD_RE = re.compile(r"[\w']+") # any whitespace or apostrophe, used to split lines below


class MRMostUsedWord(MRJob):
    STOPWORDS = {'i', 'we', 'ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than'}
    def steps(self):
        return [
            MRStep(mapper=self.mapper_get_words,
                   combiner=self.combiner_count_words,
                   reducer=self.reducer_count_words),
            MRStep(reducer=self.reducer_find_max_word)
        ]

    def mapper_get_words(self, _, line):
        # yield each word in the line
        for word in WORD_RE.findall(line):
            if word.lower() not in self.STOPWORDS:
                yield (word.lower(), 1)

    def combiner_count_words(self, word, counts):
        # optimization: sum the words we've seen so far
        yield (word, sum(counts))

    def reducer_count_words(self, word, counts):
        # send all (num_occurrences, word) pairs to the same reducer.
        # num_occurrences is used so we can easily use Python's max() function.
        yield None, (sum(counts), word)

    # discard the key; it is just None
    def reducer_find_max_word(self, _, word_count_pairs):
        # each item of word_count_pairs is (count, word),
        # so yielding one results in key=counts, value=word
        yield max(word_count_pairs)



if __name__ == '__main__':
    import time
    start = time.time()
    MRMostUsedWord.run()
    end = time.time()
    print(end - start)
# Out:
# Overwriting most_used_word.py

# %%
# !python most_used_word.py data/gutenberg/t8.shakespeare.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/most_used_word.jovyan.20210503.231750.929059
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in /tmp/most_used_word.jovyan.20210503.231750.929059/output
# Streaming final output from /tmp/most_used_word.jovyan.20210503.231750.929059/output...
# 5479	"thou"
# Removing temp directory /tmp/most_used_word.jovyan.20210503.231750.929059...
# 9.276134252548218

# %% [markdown]
# Now let's Write an mrjob script that finds the 10 words that have the most syllables from the t5.churchill.txt file

# %%
# %%file top_ten_count.py
from mrjob.job import MRJob
from mrjob.step import MRStep
from collections import defaultdict
import itertools
import re

WORD_RE = re.compile(r"[\w']+") # any whitespace or apostrophe, used to split lines below

class MRTopTenWords(MRJob):
    
    def steps(self):
        return [MRStep(mapper=self.mapper,reducer=self.reducer),MRStep(reducer = self.secondreducer)]

    
    ### input:self, _in_key, in_value
    def mapper(self, _, line):
        #yield each word in the line
        for word in WORD_RE.findall(line):
            yield (word.lower(),len(word))
            
    ### input: self, in_key from mapper, in_value from mapper        
    def reducer(self, word, chars):
        # optimization: get a single value for the words we have seen thus far
        yield None,(max(chars),word)
        
    def secondreducer(self, _, word_count_pairs): 
        word_dict= {}
        for count,word in sorted(word_count_pairs, reverse=True):
                word_dict.setdefault(count,[]).append(word)
        for result in itertools.islice(word_dict.items(), 10):
            yield  result
        
        
if __name__ == '__main__':
    MRTopTenWords.run()
# Out:
# Overwriting top_ten_count.py

# %%
# !python top_ten_count.py data/gutenberg/t5.churchill.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/top_ten_count.jovyan.20210503.231801.053313
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in /tmp/top_ten_count.jovyan.20210503.231801.053313/output
# Streaming final output from /tmp/top_ten_count.jovyan.20210503.231801.053313/output...
# 19	["straightforwardness"]
# 18	["overcapitalization", "misinterpretations", "kirkcudbrightshire", "disproportionately", "conversationalists", "characteristically"]
# 17	["uncomprehendingly", "semiconsciousness", "recrystallization", "misunderstandings", "misrepresentation", "misinterpretation", "materialistically", "incommunicability", "disinterestedness", "conventionalities", "controversialists", "conscientiousness", "communicativeness", "commissionerships", "characterizations"]
# 16	["unreasonableness", "unostentatiously", "unenforceability", "undiscriminating", "unconventionally", "unconstitutional", "uncompromisingly", "unattractiveness", "transcontinental", "susceptibilities", "superdreadnought", "superciliousness", "responsibilities", "prognostications", "prestidigitateur", "predetermination", "parliamentarians", "overenthusiastic", "nebuchadnezzar's", "misunderstanding", "lightheartedness", "intellectualized", "institutionalism", "indispensability", "incontrovertible", "incomprehensibly", "incomprehensible", "inarticulateness", "imperturbability", "enthusiastically", "disqualification", "disproportionate", "disillusionments", "disillusionizing", "disestablishment", "controversialist", "constitutionally", "conservativeness", "commissionership", "circumstantially", "characterization", "autobiographical", "anthropomorphism", "'burschenschaft'"]
# 15	["vaterlandgesang", "unsophisticated", "unprepossessing", "unparliamentary", "unobtrusiveness", "unobjectionable", "unintentionally", "ungrammatically", "unexceptionable", "understandingly", "underestimation", "undemonstrative", "unconsciousness", "unconditionally", "uncomprehending", "uncompanionable", "uncommunicative", "unceremoniously", "trustworthiness", "tempestuousness", "temperamentally", "sympathetically", "surreptitiously", "superintendents", "superintendency", "superimposition", "straightforward", "sentimentalized", "sentimentalists", "revolutionizing", "revolutionaries", "resourcefulness", "representatives", "representations", "remorselessness", "relinquishments", "recommendations", "quartermaster's", "procrastinating", "preternaturally", "presbyterianism", "postmasterships", "picturesqueness", "philosophically", "philanthropists", "pessimistically", "personification", "parthenogenesis", "overcapitalized", "obstructionists", "notwithstanding", "nottinghamshire", "neighbourliness", "misinterpreting", "misconstruction", "michilimackinac", "merchantibility", "invulnerability", "interrogatively", "interpretations", "intellectualize", "intellectuality", "instrumentality", "instantaneously", "inscrutableness", "infinitesimally", "indomitableness", "individualistic", "indissolubility", "inconsistencies", "inconsiderately", "inconsequential", "incompatibility", "inaccessibility", "impenetrability", "extraordinarily", "euphemistically", "distastefulness", "dissatisfaction", "dispassionately", "disorganization", "disillusionment", "disillusionized", "disenchantments", "discouragements", "discountenanced", "disconcertingly", "disappointments", "disappointingly", "differentiation", "democratization", "counterstriving", "cosmopolitanism", "corroboratively", "correspondingly", "conventionality", "contemplatively", "conscientiously", "congratulations", "comprehensively", "comprehendingly", "compassionately", "characteristics", "brighthelmstone", "authoritatively", "appropriateness", "acquisitiveness", "acknowledgments", "accomplishments"]
# 14	["winterhalter's", "voluptuousness", "vindictiveness", "unsuspectingly", "unsatisfactory", "unsatisfaction", "unrestrainedly", "unrecognizable", "unquestionably", "unquestionable", "unprofessional", "unpreparedness", "unpremeditated", "unpleasantness", "unintelligible", "unexpectedness", "understatement", "understandable", "undergraduates", "underestimated", "undecipherable", "unconventional", "uncontrollable", "unconscionable", "uncompromising", "uncomprehended", "unbusinesslike", "unapproachable", "unappreciative", "unacknowledged", "tremendousness", "transportation", "transparencies", "transformation", "transcendently", "technicalities", "tatterdemalion", "systematically", "supplicatingly", "superstructure", "superscription", "supersaturated", "supernaturally", "superintending", "superintendent", "superficiality", "superciliously", "superabundance", "subconsciously", "stratification", "steelengravin'", "spiritualizing", "specifications", "sophistication", "simultaneously", "sentimentality", "sentimentalist", "sentimentalism", "sensationalism", "scientifically", "schoolmistress", "satisfactorily", "ricommindation", "revolutionized", "revolutionists", "responsibility", "respectability", "representative", "representation", "reorganization", "relentlessness", "rehabilitation", "reestablishing", "reenforcements", "redistribution", "redistributing", "recriminations", "reconstruction", "reconciliation", "recommendation", "recapitulation", "reasonableness", "quartermasters", "qualifications", "providentially", "protectiveness", "proprietorship", "proportionally", "pronunciamento", "professionally", "procrastinated", "principalities", "predestination", "preconceptions", "precociousness", "precariousness", "pottawattomies", "potentialities", "postmastership", "posthelwaite's", "phosphorescent", "phlegmatically", "philosophizing", "philanthropist", "peregrinations", "pennsylvanians", "overwhelmingly", "oversuspicious", "ostentatiously", "optimistically", "obsequiousness", "northumberland", "northeastern's", "nonproprietary", "neighbourhoods", "neighborliness", "nebuchadnezzar", "municipalities", "misunderstands", "misrepresented", "misinterpreted", "misconceptions", "mesdemoiselles", "mephistopheles", "manifestations", "mademoiselle's", "lightheartedly", "liberalization", "knickerbockers", "justifications", "irreproachable", "irregularities", "investigations", "interrogations", "interpretation", "internationale", "intermittently", "interdependent", "intellectually", "insurmountable", "insuppressible", "inscrutability", "ingratiatingly", "inflammability", "individualists", "indispositions", "indiscriminate", "indeterminable", "incorporations", "inconsistently", "inconsiderably", "inconsiderable", "inconsequently", "incompleteness", "incommunicable", "inarticulately", "impressiveness", "impressionable", "imperviousness", "illuminatingly", "idiosyncrasies", "identification", "hollingsworths", "gregariousness", "gratifications", "gesticulations", "frontiersman's", "fredericksburg", "fortifications", "formidableness", "extravigancies", "extraordinaire", "expressionless", "expostulations", "experimentally", "excommunicated", "exasperatingly", "establishments", "entertainments", "entertainingly", "encyclopaedias", "encouragements", "embarrassments", "electronically", "ecclesiastical", "eccentricities", "distinguishing", "disintegration", "disintegrating", "disinheritance", "disinclination", "disillusionize", "discrimination", "discriminating", "discouragement", "discountenance", "discontinuance", "disconsolately", "disconnectedly", "discolouration", "discolorations", "disapprovingly", "disappointment", "diplomatically", "differentiated", "demonstrations", "daguerreotypes", "correspondents", "correspondence", "coquettishness", "convivialities", "conversational", "conventionally", "contradictions", "contemptuously", "contemporaries", "contemplations", "constitutional", "constituencies", "considerations", "conservatively", "congregational",  ...
# 13	["worthlessness", "worthington's", "whippoorwills", "weathersfield", "washingtonian", "vercingetorix", "unwillingness", "untrustworthy", "unsympathetic", "unsusceptible", "unsupportably", "unsupportable", "unsightliness", "unsentimental", "unselfishness", "unremittingly", "unrecommended", "unqualifiedly", "unpretentious", "unprecedented", "unpleasurable", "unobtrusively", "unnecessarily", "unmentionable", "universalized", "uninterrupted", "uninteresting", "unintentional", "unintelligent", "unimpeachable", "unimpassioned", "unimaginative", "ungentlemanly", "unfortunately", "unforgiveable", "unforgettably", "unforgettable", "unflinchingly", "unfamiliarity", "unexperienced", "unequivocally", "unenlightened", "unembarrassed", "undisguisedly", "undiscernible", "understanding", "understand'em", "undergraduate", "underestimate", "underclothing", "unconstrained", "unconsecrated", "unconsciously", "unconformable", "unconcernedly", "uncomplaining", "uncomfortably", "uncomfortable", "unceremonious", "unapprehended", "unanticipated", "unaccountably", "unaccountable", "unaccompanied", "trolksmelodie", "tremulousness", "transientness", "transgressors", "transgression", "transfiguring", "transcription", "transatlantic", "tobacconist's", "thunderstruck", "threateningly", "thoroughfares", "thoroughbreds", "theoretically", "terpsichorean", "temperamental", "tankerville's", "symmetrically", "surreptitious", "supplications", "superstitious", "superstitions", "superintended", "superhumanity", "superfluously", "superannuated", "superabundant", "substantiated", "substantially", "subordinating", "strangulation", "straightening", "storekeeper's", "stockholders'", "stenographers", "steeplechases", "statesmanship", "statesmanlike", "squeamishness", "sportsmanship", "spontaneously", "sponginghouse", "spiritualized", "spectatorship", "spasmodically", "sophisticated", "socialization", "sleeplessness", "significantly", "sharpshooters", "shakespearian", "shakespeare's", "sentimentally", "sententiously", "sensitiveness", "sensibilities", "semiconscious", "secretiveness", "secessionists", "seaworthiness", "scintillating", "schoolteacher", "scatterbrains", "sarcastically", "sanctimonious", "sacerdotalism", "righteousness", "revolutionist", "revolutionary", "reverberation", "reverberating", "retrospective", "retrospection", "retrogression", "resuscitation", "restrainingly", "republicanism", "reproachfully", "reprehensible", "renunciations", "remorselessly", "remonstrating", "remonstrances", "reminiscently", "reminiscences", "relinquishing", "relationships", "reinstatement", "reincarnation", "rehabilitated", "reestablished", "reenforcement", "redemptioners", "recrimination", "reconstructed", "reconnoitered", "recommembered", "recollections", "reappointment", "reaffirmation", "rationalistic", "ratifications", "ramifications", "questioningly", "querulousness", "quartermaster", "qualification", "psychologists", "psychological", "provinciality", "provincialism", "protestations", "protestantism", "pronunciation", "pronouncement", "professionals", "proclamations", "problematical", "probabilities", "prevarication", "prepossessing", "preponderance", "preoccupation", "premeditation", "preliminaries", "predominating", "predilections", "precipitation", "precipitating", "precipitately", "precautionary", "practitioners", "powerlessness", "possibilities", "picturesquely", "physiologists", "physiognomies", "photographers", "philosophized", "philosophical", "philosopher's", "philanthropic", "personalities", "perpendicular", "perfunctorily", "perambulators", "pennsylvanian", "penetratingly", "penetrability", "pedagogically", "peculiarities", "patronizingly", "particularize", "participation", "parliamentary", "parli'ment'ry", "parallelogram", "paradoxically", "palpitatingly", "painstakingly", "overshadowing", "overestimated", "overconfident", "overabundance", "outspokenness", "ornamentation", "organizations", "opprobriously", "opportunities", "northeastward", "nonconformity", " ...
# 12	["worthingtons", "workingmen's", "withstanding", "winterbourne", "williamstown", "williamson's", "williamsburg", "whoremongers", "whittlesey's", "whitewashing", "whippoorwill", "whimsicality", "watchfulness", "washington's", "walkingstick", "volunteering", "vociferously", "vituperation", "vindictively", "vilification", "victoriously", "vicissitudes", "valenciennes", "uproariously", "upholsterers", "unventilated", "untranslated", "untrammelled", "unthinkingly", "unsuspecting", "unsuccessful", "unsteadiness", "unsquandered", "unskillfully", "unscrupulous", "unscientific", "unsanctified", "unrestrained", "unresponsive", "unreservedly", "unregenerate", "unrecognized", "unreasonably", "unreasonable", "unrealizable", "unquestioned", "unquenchable", "unprotesting", "unpropitious", "unpronounced", "unprofitable", "unproductive", "unprincipled", "unprejudiced", "unpopularity", "unpleasantly", "unpardonable", "unparalleled", "unofficially", "unobstructed", "unmistakably", "unmistakable", "unmercifully", "unmanageable", "universities", "universalize", "universalist", "unitarianism", "uninfluenced", "unimpressive", "unimportance", "unimaginable", "unidentified", "ungovernable", "ungenerously", "unfrequented", "unfortunates", "unformulated", "unforgetable", "unflaggingly", "unfavourably", "unfavourable", "unfathomable", "unexpectedly", "undiscovered", "undiscerning", "undiminished", "undetermined", "underwriting", "undervaluing", "undertakings", "undercurrent", "underclothes", "undemocratic", "unconvincing", "uncontrolled", "unchangeable", "unchallenged", "unblushingly", "unbelievably", "unbelievable", "unattainable", "unassailable", "unanswerable", "unaggressive", "unacquainted", "unaccustomed", "tumultuously", "tuberculosis", "truthfulness", "trustfulness", "trowbridges'", "trowbridge's", "trivialities", "triumphantly", "trigonometry", "tribulations", "tremendously", "transporting", "transplanted", "transmitting", "transmitters", "transmission", "transitional", "transgressor", "transgressed", "transforming", "transfigured", "transference", "transcending", "transcendent", "transactions", "tranquillity", "tradespeople", "thundercloud", "thunderbolts", "threadneedle", "thoughtfully", "thoroughness", "thoroughfare", "thoroughbred", "thistledowns", "thingumajigs", "themistocles", "theatregoers", "thanksgiving", "thankfulness", "tetherington", "temperaments", "telegraphing", "technicality", "tanglefoot's", "syndicalists", "sympathizing", "sympathizers", "suspiciously", "surveillance", "surroundings", "surrendering", "surrejoinder", "surprisingly", "supplication", "supplicating", "supplemented", "superstition", "supernatural", "superlatives", "superimposed", "supercilious", "sup'stitious", "summerthough", "sufficiently", "successively", "successfully", "substituting", "substantiate", "subserviency", "subservience", "subsequently", "subscription", "subordinates", "sublapsarian", "subjectivism", "subconscious", "stupefaction", "stubbornness", "strengthened", "strawberries", "straitjacket", "straightness", "straightened", "stradivarius", "storekeepin'", "storekeepers", "stockholders", "stereopticon", "stenographer", "steeplechase", "steamboating", "standardized", "spitalfields", "spiritualize", "spirituality", "spendthrifts", "speechmaking", "speculations", "specifically", "spaciousness", "southwestern", "southerner's", "somnambulism", "solicitously", "solicitation", "sociologists", "sociological", "snobbishness", "slaveholders", "slaughtering", "skyrocketing", "simultaneous", "significance", "shudderingly", "shortcomings", "shipbuilding", "shamefacedly", "shaksperiana", "shakespheare", "sh'poloshize", "senatorships", "semidarkness", "semicircular", "secessionist", "searchlights", "scrutinizing", "scrupulously", "scripturally", "schoolmaster", "scandinavian", "scandalously", "satisfactory", "satisfaction", "sardonically", "safeguarding", "sacrilegious", "ruthlessness", "rutherford's", "romantically", "rocheblave's", "ridiculously", "richardson' ...
# 11	["zudendorffs", "yesterday's", "wrottleseys", "worthington", "worshipping", "worshippers", "worldliness", "workmanship", "wonderingly", "wonderfully", "womanliness", "wo'thington", "withholding", "witherspoon", "withdrawing", "wistfulness", "willingness", "williamsons", "wilkinson's", "wilberforce", "widowerhood", "whitsuntide", "whitmarsh's", "whitewashed", "whisperings", "whimsically", "whigmeleery", "whereabouts", "wetherell's", "westminster", "westchester", "wentworth's", "weathervane", "weathercock", "waywardness", "watermelons", "warmhearted", "warlencourt", "wakefulness", "wainscoting", "volunteered", "voluntarily", "vivaciously", "visualizing", "visitations", "visionaries", "vindication", "vinaigrette", "vicemongers", "vicariously", "versatility", "venturesome", "ventilation", "varmints'll", "valentine's", "vacillating", "utilitarian", "uselessness", "upholstered", "unwittingly", "unwillingly", "unwholesome", "unwarranted", "unvarnished", "unutterable", "untormented", "unthinkable", "untarnished", "unsuspected", "unsurpassed", "unsupported", "unspeakable", "unsolicited", "unselfishly", "unscratched", "unsatisfied", "unrighteous", "unrestraint", "unresisting", "unrepressed", "unrepentant", "unremitting", "unrelenting", "unreceptive", "unreasoning", "unrealities", "unravelling", "unqualified", "unprotected", "unpromising", "unprintable", "unpractised", "unperturbed", "unperceived", "unpatriotic", "unpalatable", "unorganized", "unobtrusive", "unobserving", "unnecessary", "unnaturally", "unmitigated", "unlookedfor", "university'", "universally", "uninspiring", "uninitiated", "unimpressed", "unimportant", "unharnessed", "unhappiness", "unguardedly", "ungratified", "unfulfilled", "unfortunate", "unforgetful", "unflinching", "unfaltering", "unexpressed", "unexplained", "unescapable", "unequivocal", "unemotional", "undoubtedly", "undisturbed", "undisguised", "undisclosed", "undiscerned", "undeveloped", "undesirable", "undervalued", "undertaking", "understated", "understands", "undermining", "underhanded", "undergrowth", "underground", "uncouthness", "unconvinced", "unconscious", "unconquered", "unconnected", "uncongenial", "unconformed", "unconfirmed", "uncondemned", "unconcerned", "unconceived", "unconcealed", "unchristian", "unchartable", "uncertainty", "uncertainly", "unceasingly", "unbuttoning", "unbribeable", "unbreakable", "unbelieving", "unavoidably", "unavoidable", "unannounced", "unanimously", "unalterable", "unadvisedly", "ultramarine", "typewritten", "typewriting", "typewriters", "trustworthy", "trusteeship", "truesdale's", "truculently", "troublesome", "tributaries", "trespassing", "trespassers", "trepidation", "tremulously", "tremblingly", "treecherous", "treasurer's", "treasonable", "treacherous", "transported", "transparent", "transmitter", "transmitted", "translucent", "translation", "translating", "transitions", "transformed", "transferred", "transcribed", "transcended", "transaction", "traditional", "townspeople", "townshend's", "tourniquets", "tobogganing", "toastmaster", "ticonderoga", "thunderbolt", "thumbscrews", "threatening", "thoughtless", "thermometer", "thereabouts", "theoretical", "theological", "theologians", "theatricals", "thanatopsis", "testimonial", "tessellated", "territories", "territorial", "terrestrial", "terpsichore", "terminology", "terminating", "tentatively", "tenaciously", "temptations", "temporizing", "temporarily", "temperature", "temperately", "temperament", "telephoning", "telegraphed", "tediousness", "technically", "tantalizing", "talleyrands", "talebearing", "taciturnity", "syndicalist", "syndicalism", "synchronous", "symptomatic", "sympathizes", "sympathizer", "sympathized", "sympathique", "sympathetic", "symmetrical", "symbolizing", "switzerland", "sweethearts", "swallowtail", "suspicioned", "susceptible", "surrounding", "surrendered", "surrebutter", "surmounting", "suppression", "suppressing", "supposition", "supportable", "supplements", "supervision", "supervising", "super ...
# 10	["zigzagging", "zealanders", "zaccarelli", "yourselves", "youngsters", "yereselves", "yankeeland", "wrottlesey", "wrongfully", "wretchedly", "wrathfully", "worthiness", "worshipper", "worshipped", "worshipful", "workingmen", "workingman", "workbasket", "wordsworth", "woodsman's", "woodpecker", "woodchucks", "wondrously", "wonderment", "wonderland", "womenfolks", "witticisms", "wittenburg", "witnessing", "withstands", "withdrawal", "windshield", "windowsill", "windowless", "windlasses", "williams's", "wilfulness", "wildflower", "wilderness", "widespread", "wideawakes", "wicketgate", "wickedness", "whomsoever", "whittlesey", "whitehaven", "whitcomb's", "whispering", "whisperin'", "whiskbroom", "whereinell", "wheelock's", "whatsoever", "wetherells", "wetherell'", "westerning", "westerners", "wellington", "wednesdays", "wedgwood's", "wedderburn", "weathering", "weaknesses", "waterproof", "waterpower", "waterfords", "waterfalls", "watchman's", "watchmaker", "watchfully", "washington", "washin'ton", "warranties", "warfield's", "warehouses", "wantshtobe", "wanderings", "waitresses", "waistcoats", "wainscoted", "wagonettes", "vulnerable", "voyageurs'", "vouchsafed", "volunteers", "voluminous", "volontiers", "vociferous", "vocabulary", "vituperate", "vitalizing", "visualized", "visualised", "visitation", "virginians", "virginia's", "violations", "vindictive", "vindicated", "vigorously", "victorious", "victoria's", "vicomtesse", "vibrations", "veterinary", "vestibules", "versailles", "vernacular", "ventilated", "vengefully", "veneration", "velocipede", "vehemently", "vegetables", "vaudeville", "vanquishes", "valentines", "vagabondia", "utterances", "usefulness", "upstanding", "uproarious", "upholstery", "upbuilding", "upbraiding", "unyielding", "unwontedly", "unwearying", "unwavering", "untroubled", "unthinking", "untethered", "unswerving", "unsummoned", "unsteadily", "unsolvable", "unsociable", "unskillful", "unsheathed", "unshakable", "unscrewing", "unromantic", "unrewarded", "unrevealed", "unreproved", "unreliable", "unrealized", "unravelled", "unquenched", "unpunished", "unprepared", "unpleasing", "unpleasant", "unorthodox", "unoccupied", "unobserved", "unmolested", "unmerciful", "unmeasured", "unlettered", "university", "uniqueness", "unimposing", "unimpaired", "unimagined", "unhygienic", "unheralded", "unhampered", "ungrateful", "ungracious", "ungraceful", "unfriendly", "unforeseen", "unflagging", "unfinished", "unfettered", "unfastened", "unfamiliar", "unfaithful", "unexplored", "unexploded", "unexpected", "unexampled", "uneventful", "unerringly", "unenviable", "unemployed", "uneducated", "uneasiness", "undulating", "undressing", "undisputed", "undisposed", "undismayed", "underwrite", "undervalue", "undertones", "undertakes", "undertaker", "undertaken", "understudy", "understood", "understate", "understand", "understan'", "undersized", "underscore", "underrated", "underneath", "undermined", "underlying", "underlings", "undergoing", "underbrush", "undeniably", "undeniable", "undefeated", "undeceived", "undampened", "unctuously", "uncrossing", "unconfided", "uncommonly", "uncoloured", "unchaining", "unbuttoned", "unburdened", "unbetrayed", "unbeliever", "unbecoming", "unbearably", "unbearable", "unbaptized", "unavailing", "unattended", "unattached", "unassuming", "unappeased", "unaffected", "unachieved", "unabridged", "ultimately", "ubiquitous", "tyrannical", "typewriter", "twittering", "turpentine", "turnverein", "turbulence", "tumultuous", "tumbledown", "truthfully", "trustfully", "trumpeting", "truculence", "trowbridge", "triviality", "triumphant", "tricolored", "tricksters", "tricklings", "triangular", "tremendous", "treeshaded", "treasurers", "travesties", "traversing", "travelling", "travellers", "transverse", "transports", "transpired", "transmuted", "translated", "transitory", "transition", "transience", "transgress", "transfixed", "transcribe", "transacted", "tranquilly", "trammelled", "traitorous", "tragically", "traff ...
# Removing temp directory /tmp/top_ten_count.jovyan.20210503.231801.053313...
